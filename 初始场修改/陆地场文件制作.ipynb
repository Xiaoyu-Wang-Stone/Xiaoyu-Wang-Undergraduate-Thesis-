# %%
import numpy as np
from netCDF4 import Dataset
file_test = Dataset('/Users/wangxiaoyu/Desktop/CESM/res.clm2.r.0002-01-01-00000.nc', mode = 'a')

timemgr_rst_nstep_rad_prev = file_test.variables['timemgr_rst_nstep_rad_prev'][:] 
timemgr_rst_type = file_test.variables['timemgr_rst_type'][:] 
timemgr_rst_step_sec = file_test.variables['timemgr_rst_step_sec'][:] 

timemgr_rst_start_ymd  = file_test.variables['timemgr_rst_start_ymd'][:] 
timemgr_rst_start_tod = file_test.variables['timemgr_rst_start_tod'][:] 

timemgr_rst_ref_ymd = file_test.variables['timemgr_rst_ref_ymd'][:] 
timemgr_rst_ref_tod = file_test.variables['timemgr_rst_ref_tod'][:] 

timemgr_rst_curr_ymd = file_test.variables['timemgr_rst_curr_ymd'][:] 
timemgr_rst_curr_tod = file_test.variables['timemgr_rst_curr_tod'][:] 

mcdate = file_test.variables['mcdate'][:] 
mcsec = file_test.variables['mcsec'][:] 

file_back = Dataset('/Users/wangxiaoyu/Desktop/CESM/b40.1850.track1.2deg.003.clm2.r.0401-01-01-00000.nc', mode = 'a')
timemgr_rst_nstep_rad_prev_back = file_back.variables['timemgr_rst_nstep_rad_prev'][:] 
timemgr_rst_type_back = file_back.variables['timemgr_rst_type'][:] 
timemgr_rst_step_sec_back = file_back.variables['timemgr_rst_step_sec'][:] 
timemgr_rst_start_ymd_back  = file_back.variables['timemgr_rst_start_ymd'][:] 
timemgr_rst_start_tod_back = file_back.variables['timemgr_rst_start_tod'][:] 
timemgr_rst_ref_ymd_back = file_back.variables['timemgr_rst_ref_ymd'][:] 
timemgr_rst_ref_tod_back = file_back.variables['timemgr_rst_ref_tod'][:] 
timemgr_rst_curr_ymd_back = file_back.variables['timemgr_rst_curr_ymd'][:] 
timemgr_rst_curr_tod_back = file_back.variables['timemgr_rst_curr_tod'][:] 
mcdate_back = file_back.variables['mcdate'][:] 
mcsec_back = file_back.variables['mcsec'][:] 

#setting
timemgr_rst_nstep_rad_prev = timemgr_rst_nstep_rad_prev_back
timemgr_rst_type = timemgr_rst_type_back
timemgr_rst_step_sec = timemgr_rst_step_sec_back

timemgr_rst_start_ymd = timemgr_rst_start_ymd_back
timemgr_rst_start_tod = timemgr_rst_start_tod_back

timemgr_rst_ref_ymd = timemgr_rst_ref_ymd_back
timemgr_rst_ref_tod = timemgr_rst_ref_tod_back

timemgr_rst_curr_ymd = timemgr_rst_curr_ymd_back
timemgr_rst_curr_tod = timemgr_rst_curr_tod_back

mcdate = mcdate_back
mcsec = mcsec_back
    

file_test.variables['timemgr_rst_nstep_rad_prev'][:] = timemgr_rst_nstep_rad_prev
file_test.variables['timemgr_rst_type'][:] = timemgr_rst_type
file_test.variables['timemgr_rst_step_sec'][:] = timemgr_rst_step_sec
file_test.variables['timemgr_rst_start_ymd'][:] = timemgr_rst_start_ymd
file_test.variables['timemgr_rst_start_tod'][:]  = timemgr_rst_start_tod
file_test.variables['timemgr_rst_ref_ymd'][:] = timemgr_rst_ref_ymd
file_test.variables['timemgr_rst_ref_tod'][:] = timemgr_rst_ref_tod
file_test.variables['timemgr_rst_curr_ymd'][:] = timemgr_rst_curr_ymd
file_test.variables['timemgr_rst_curr_tod'][:]  = timemgr_rst_curr_tod
file_test.variables['mcdate'][:] = mcdate
file_test.variables['mcsec'][:] = mcsec
file_test.close()
